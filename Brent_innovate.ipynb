# %%
html_full = """<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0" />
  <title>Brent Innovate</title>
  <link rel="stylesheet" href="styles.css" />
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700&display=swap" rel="stylesheet" />
</head>
<body>
  <!-- NAVBAR -->
  <header class="navbar">
    <div class="logo">
      <img src="brent-logo.png" alt="Brent Logo" class="logo-img" />
      <span class="logo-text">Brent <strong>Innovate</strong></span>
    </div>
    <nav>
      <ul>
        <li><a href="#">Technology</a></li>
        <li><a href="#">Services</a></li>
        <li><a href="#">Resources</a></li>
        <li><a href="#">Company</a></li>
        <li><a href="#">Careers</a></li>
      </ul>
    </nav>
    <a href="#" class="btn primary">Get Started</a>
  </header>

  <!-- HERO -->
  <section class="hero">
    <div class="hero-text">
      <h1>Explore.<br>Innovate.<br>Succeed.</h1>
      <p>AI-powered tools and services helping businesses unlock limitless possibilities.</p>
      <div class="hero-buttons">
        <a href="#" class="btn primary">Get Started</a>
        <a href="#" class="btn secondary">Learn More</a>
      </div>
    </div>
    <canvas id="network-bg"></canvas>
  </section>

  <!-- Brent AI Platform -->
  <section class="platform">
    <h2>Brent AI Platform</h2>
    <div class="platform-grid">
      <div class="platform-card">
        <div class="icon">💬</div>
        <h3>Chat AI</h3>
      </div>
      <div class="platform-card">
        <div class="icon">🤖</div>
        <h3>AI Person</h3>
      </div>
      <div class="platform-card">
        <div class="icon">👕</div>
        <h3>Virtual Try-On</h3>
      </div>
      <div class="platform-card">
        <div class="icon">💡</div>
        <h3>Intelligent Decorator</h3>
      </div>
    </div>
    <a href="#" class="explore-link">Explore the Platform →</a>
  </section>

  <!-- Services Section -->
  <section class="services">
    <h2>Brent Innovate Services</h2>
    <br>
    <div class="services-grid">
      <div class="service-card">
        <h3>Consulting</h3>
        <p>Strategize audiences, align ROI goals, and unlock new possibilities through data-driven insights.</p>
        <a href="#" class="btn secondary">Learn More</a>
      </div>
      <div class="service-card">
        <h3>Training</h3>
        <p>Empower your team with the latest in AI tools, deep learning techniques, and innovation programs.</p>
        <a href="#" class="btn secondary">Learn More</a>
      </div>
      <div class="testimonial">
        <blockquote>“Working with Brent Innovate has been a game changer.”</blockquote>
        <p class="client">– Apispace</p>
      </div>
    </div>
  </section>

  <!-- Case Studies -->
  <section class="case-studies">
    <h2>Case Studies</h2>
    <br>
    <div class="cases">
      <div class="case">
        <h3>+30%</h3>
        <p>increase in diagnostic accuracy for healthcare.</p>
      </div>
      <div class="case">
        <h3>40%</h3>
        <p>reduction in fraud for finance industry.</p>
      </div>
    </div>
    <a href="#" class="explore-link">Request a Demo →</a>
  </section>

  <!-- Footer -->
  <footer class="footer">
    <div class="contact">
      <h3>Contact Us</h3>
      <form>
        <input type="text" placeholder="Name" required>
        <input type="email" placeholder="Email" required>
        <textarea placeholder="Message" rows="4"></textarea>
        <button type="submit" class="btn primary">Send</button>
      </form>
    </div>
    <div class="footer-info">
      <h4>Brent Innovate</h4>
      <p> London, United Kingdom </p>
      <p>info@brentinnovate.com</p>
      <p>© 2025 Brent Innovate. All rights reserved.</p>
    </div>
  </footer>

  <script src="network.js"></script>
</body>
</html>"""

with open("index.html", "w", encoding="utf-8") as f:
    f.write(html_full)

print("✓ index.html created successfully (no 'Join Our Team' section)")
# Out:
# ✓ index.html created successfully (no 'Join Our Team' section)

# %%
css_full = """*{margin:0;padding:0;box-sizing:border-box}
body{
  font-family:'Inter',sans-serif;
  color:#0d1a2d;
  background:linear-gradient(to bottom right,#f4fcfd,#e9f5f8);
  overflow-x:hidden;
}

/* Navbar */
.navbar{
  display:flex;justify-content:space-between;align-items:center;
  padding:20px 60px;background:#fff;
  box-shadow:0 2px 8px rgba(0,0,0,.05);
  position:sticky;top:0;z-index:10;
}
.logo{display:flex;align-items:center;gap:2px;}
.logo-img{width:100px;height:100px;object-fit:contain;}
.logo-text{font-size:1.3rem;font-weight:600;color:#0d1a2d;}
nav ul{list-style:none;display:flex;gap:30px;}
nav a{text-decoration:none;font-weight:500;color:#0d1a2d;transition:color .2s;}
nav a:hover{color:#1a3c78;}

/* Buttons */
.btn{text-decoration:none;font-weight:600;padding:10px 22px;border-radius:8px;transition:all .25s ease;display:inline-block;}
.primary{background:#1a3c78;color:#fff;}
.primary:hover{background:#244b93;}
.secondary{border:2px solid #1a3c78;color:#1a3c78;}
.secondary:hover{background:#1a3c78;color:#fff;}

/* Hero Section */
.hero{position:relative;display:flex;align-items:center;gap:40px;height:90vh;padding:100px 60px;overflow:hidden;}
.hero-text{z-index:2;max-width:620px;}
.hero-text h1{font-size:70px;line-height:1.15;font-weight:700;color:#0d1a2d;}
.hero-text p{margin:20px 0 30px;font-size:18px;color:#2a3b4d;max-width:520px;}
.hero-buttons{display:flex;gap:20px;}
#network-bg{position:absolute;top:0;right:0;height:100%;width:min(55vw,780px);opacity:.45;z-index:1;pointer-events:none;-webkit-mask-image:linear-gradient(to left,rgba(0,0,0,1),rgba(0,0,0,0.05));mask-image:linear-gradient(to left,rgba(0,0,0,1),rgba(0,0,0,0.05));}

/* Platform */
.platform{text-align:center;background:#f7fbfc;padding:80px 60px;}
.platform-grid{display:flex;justify-content:center;flex-wrap:wrap;gap:30px;}
.platform-card{background:white;border-radius:16px;box-shadow:0 4px 10px rgba(0,0,0,0.05);padding:30px 40px;width:220px;}
.platform-card .icon{font-size:36px;margin-bottom:10px;}
.explore-link{display:inline-block;margin-top:30px;color:#1a3c78;font-weight:600;text-decoration:none;}

/* Services */
.services{background:linear-gradient(90deg,#e8f6f7,#d5f1f4);padding:80px 60px;}
.services-grid{display:grid;grid-template-columns:repeat(auto-fit,minmax(260px,1fr));gap:70px;}
.service-card,.testimonial{background:white;border-radius:12px;padding:30px;box-shadow:0 4px 8px rgba(0,0,0,0.05);}
.testimonial{background:linear-gradient(135deg,#1a3c78,#007b99);color:white;display:flex;flex-direction:column;justify-content:center;}
blockquote{font-size:18px;font-style:italic;margin-bottom:10px;}
.client{text-align:right;font-size:14px;}

/* Case Studies */
.case-studies{text-align:center;background:white;padding:80px 60px;}
.cases{display:flex;justify-content:center;gap:60px;flex-wrap:wrap;}
.case h3{font-size:40px;color:#1a3c78;}
.case p{color:#2a3b4d;max-width:200px;}

/* Footer */
.footer{background:#f4f8fa;display:flex;justify-content:space-between;flex-wrap:wrap;padding:60px;}
.contact form{display:flex;flex-direction:column;gap:12px;}
.contact input,.contact textarea{padding:12px;border-radius:6px;border:1px solid #ccc;font-size:15px;}
.footer-info{max-width:300px;}
.footer-info h4{margin-bottom:10px;}

/* Responsive */
@media(max-width:900px){
  .hero{flex-direction:column;text-align:center;padding:60px 24px;height:auto;}
  .hero-text h1{font-size:48px;}
  .hero-text p{font-size:16px;margin-bottom:24px;}
  nav ul{display:none;}
  .cases{gap:30px;}
}
"""

with open("styles.css", "w", encoding="utf-8") as f:
    f.write(css_full)

print("✓ styles.css created successfully")
# Out:
# ✓ styles.css created successfully

# %%
js_code = r"""const canvas = document.getElementById('network-bg');
const ctx = canvas.getContext('2d', { alpha: true });

let nodes = [];
let dpr = Math.max(1, window.devicePixelRatio || 1);

function sizeCanvas(){
  const rect = canvas.getBoundingClientRect();
  canvas.width  = Math.floor(rect.width  * dpr);
  canvas.height = Math.floor(rect.height * dpr);
  ctx.setTransform(dpr, 0, 0, dpr, 0, 0);
}

function initNodes(){
  nodes = [];
  const area = (canvas.width/dpr) * (canvas.height/dpr);
  const count = Math.max(28, Math.floor(area / 12000));
  for(let i=0;i<count;i++){
    nodes.push({
      x: Math.random()*(canvas.width/dpr),
      y: Math.random()*(canvas.height/dpr),
      vx: (Math.random()*0.4-0.2),
      vy: (Math.random()*0.4-0.2)
    });
  }
}

function draw(){
  ctx.clearRect(0,0,canvas.width/dpr,canvas.height/dpr);

  for(let i=0;i<nodes.length;i++){
    const n = nodes[i];
    n.x += n.vx; n.y += n.vy;
    if(n.x<0||n.x>canvas.width/dpr)  n.vx *= -1;
    if(n.y<0||n.y>canvas.height/dpr) n.vy *= -1;

    ctx.beginPath();
    ctx.arc(n.x, n.y, 3, 0, Math.PI*2);
    ctx.fillStyle = '#1a3c78';
    ctx.fill();

    for(let j=i+1;j<nodes.length;j++){
      const m = nodes[j];
      const dist = Math.hypot(n.x-m.x, n.y-m.y);
      if(dist < 160){
        ctx.strokeStyle = 'rgba(26, 60, 120, 0.25)';
        ctx.lineWidth = 1;
        ctx.beginPath();
        ctx.moveTo(n.x,n.y);
        ctx.lineTo(m.x,m.y);
        ctx.stroke();
      }
    }
  }
  requestAnimationFrame(draw);
}

function setup(){
  sizeCanvas();
  initNodes();
  draw();
}

window.addEventListener('resize', setup);
setup();
"""

with open("network.js", "w", encoding="utf-8") as f:
    f.write(js_code)

print("✓ network.js created successfully (animated background ready)")
# Out:
# ✓ network.js created successfully (animated background ready)

# %%
service_spacing_css = """
/* Improved spacing for Services section */
.service-card {
  display: flex;
  flex-direction: column;
  justify-content: space-between;
  gap: 14px;             
 /* spacing between elements */
}

.service-card h3 {
  font-size: 22px;
  font-weight: 600;
  color: #0d1a2d;
}

.service-card p {
  line-height: 1.6;
  font-size: 16px;
  color: #2a3b4d;
}

.service-card .btn {
  margin-top: 10px;
  align-self: flex-start;
}
"""

with open("styles.css", "a", encoding="utf-8") as f:
    f.write(service_spacing_css)

print("✓ Added spacing between heading, text, and button in service cards")

platform_heading_spacing = """
/* Add space below Brent AI Platform heading */
.platform h2 {
  margin-bottom: 40px;  /* controls the gap under the heading */
}
"""

with open("styles.css", "a", encoding="utf-8") as f:
    f.write(platform_heading_spacing)

print("✓ Added spacing below 'Brent AI Platform' heading")
# Out:
# ✓ Added spacing between heading, text, and button in service cards
# ✓ Added spacing below 'Brent AI Platform' heading

# %%
import os, webbrowser
webbrowser.open('file://' + os.path.abspath('index.html'))
# Out:
# True

# %%
# !pip install pdfkit
# !brew install wkhtmltopdf 

import sys
import subprocess

subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'pdfkit'])
# Out:
# ...
# zsh:1: command not found: brew
# ...
# 0

# %%
import pdfkit

# Path to your HTML file
input_path = "index.html"
output_path = "Brent_Innovate_Website.pdf"
config = pdfkit.configuration(wkhtmltopdf='/usr/local/bin/wkhtmltopdf')  # Replace with your actual path

# Convert to PDF with configuration
pdfkit.from_file(input_path, output_path, configuration=config)

print(f"✓ PDF created successfully: {output_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pdfkit/configuration.py:35, in Configuration.__init__(self, wkhtmltopdf, meta_tag_prefix, environ)
#      33     self.wkhtmltopdf = lines[0].strip()
# ---> 35 with open(self.wkhtmltopdf) as f:
#      36     pass
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/bin/wkhtmltopdf'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[50], line 6
#       4 input_path = "index.html"
#       5 output_path = "Brent_Innovate_Website.pdf"
# ----> 6 config = pdfkit.configuration(wkhtmltopdf='/usr/local/bin/wkhtmltopdf')  # Replace with your actual path
#       8 # Convert to PDF with configuration
# ...
